-- %% [markdown]
-- # [dbo].[nvdKhoa]

-- %%
USE [NVDK22CNT3_Lession07Db]
GO

-- %%
/****** Object:  Table [dbo].[nvdKhoa]    Script Date: 6/12/2024 9:17:27 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[nvdKhoa](
	[NvdMaKH] [nchar](10) NOT NULL,
	[NvdTenKH] [nvarchar](50) NULL,
	[NvdTrangThai] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[NvdMaKH] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[nvdSinhVien]

-- %%
/****** Object:  Table [dbo].[nvdSinhVien]    Script Date: 6/12/2024 9:17:27 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[nvdSinhVien](
	[NvdMaSV] [nvarchar](50) NOT NULL,
	[NvdHoSV] [nvarchar](50) NULL,
	[NvdTenSV] [nvarchar](50) NULL,
	[NvdNgaySinh] [date] NULL,
	[NvdPhai] [bit] NULL,
	[NvdPhone] [nchar](10) NULL,
	[NvdEmail] [nvarchar](50) NULL,
	[NvdMaKH] [nchar](10) NULL,
PRIMARY KEY CLUSTERED 
(
	[NvdMaSV] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_nvdKhoa_nvdSinhVien]

-- %%
ALTER TABLE [dbo].[nvdSinhVien]  WITH CHECK ADD  CONSTRAINT [FK_nvdKhoa_nvdSinhVien] FOREIGN KEY([NvdMaKH])
REFERENCES [dbo].[nvdKhoa] ([NvdMaKH])
GO
ALTER TABLE [dbo].[nvdSinhVien] CHECK CONSTRAINT [FK_nvdKhoa_nvdSinhVien]
GO
